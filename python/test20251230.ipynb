# %% [markdown]
# <a href="https://colab.research.google.com/github/gilbertHsieh0106/mslearn-create-razor-pages-aspnet-core/blob/main/python/test20251230.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test of colab")
# Out:
# test of colab
